# %% [markdown]
# <a href="https://colab.research.google.com/github/AAdi-112/platewatch-yolo-v11/blob/main/platewatch_yolo-v11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ROBOFLOW_API_KEY")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(11)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 80.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 119.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=undefined&ref=undefined
# loading Roboflow workspace...
# ...

# %%
# !ls /content/License-Plate-Recognition-11/roboflow.zip
# Out:
# /content/License-Plate-Recognition-11/roboflow.zip

# %%
from ultralytics import YOLO
model=YOLO("yolo11n.pt")

train_resuls = model.train(
    data="/content/License-Plate-Recognition-11/data.yaml",
    epochs=5, imgsz=640

)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.predict(
    source="/content/License-Plate-Recognition-11/valid/images/00071c51c8e92a68_jpg.rf.446f345e7d5974082616d32dd8eb3d27.jpg"
)

for r in results:
    r.save(filename="output.jpg")
    r.show()
# Out:
# image 1/1 /content/License-Plate-Recognition-11/valid/images/00071c51c8e92a68_jpg.rf.446f345e7d5974082616d32dd8eb3d27.jpg: 640x640 1 License_Plate, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
results = model.predict(
    source="/content/License-Plate-Recognition-11/valid/images/004fddebf0ac943c_jpg.rf.0fec71a36784316f943af4dd515d061d.jpg"
)

for r in results:
    r.save(filename="output.jpg")
    r.show()
# Out:
# image 1/1 /content/License-Plate-Recognition-11/valid/images/004fddebf0ac943c_jpg.rf.0fec71a36784316f943af4dd515d061d.jpg: 640x576 2 License_Plates, 9.2ms
# Speed: 4.1ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 576)
# <PIL.Image.Image image mode=RGB size=920x1024>
